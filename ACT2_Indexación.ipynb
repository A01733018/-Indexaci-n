# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listings.csv")
df
# Out:
#                         id                                       listing_url  \
# 0                   538175               https://www.airbnb.com/rooms/538175
# 1                   541221               https://www.airbnb.com/rooms/541221
# 2                   541668               https://www.airbnb.com/rooms/541668
# 3                   544809               https://www.airbnb.com/rooms/544809
# 4                   553285               https://www.airbnb.com/rooms/553285
# ...                    ...                                               ...
# 22535  1444043842204694335  https://www.airbnb.com/rooms/1444043842204694335
# 22536  1444134511111522063  https://www.airbnb.com/rooms/1444134511111522063
# 22537  1444209901012550835  https://www.airbnb.com/rooms/1444209901012550835
# 22538  1444251694855590556  https://www.airbnb.com/rooms/1444251694855590556
# 22539  1444265456512525732  https://www.airbnb.com/rooms/1444265456512525732
#
# ...

# %%
# Acceder a más de una Columna (Array 2D)
columnas1 = df[['host_name', 'host_since','host_neighbourhood', 'property_type', 'room_type','price']] #pueden ser consecutivas o no consecutivas
columnas1
# Out:
#              host_name  host_since  host_neighbourhood       property_type  \
# 0              Barbara  2012-06-15                 NaN         Entire loft
# 1                Elena  2011-11-25                 NaN  Entire rental unit
# 2               Matteo  2012-03-28              Zona 4        Entire condo
# 3         Paolo & Yuki  2012-05-24        Porta Romana  Entire rental unit
# 4               Nicola  2012-06-23  Centro Direzionale  Entire rental unit
# ...                ...         ...                 ...                 ...
# 22535          Luciano  2025-06-15                 NaN  Entire rental unit
# 22536           Enrico  2012-06-07                 NaN       Room in hotel
# 22537           Davide  2019-10-21                 NaN  Entire rental unit
# 22538         Concetta  2025-06-15                 NaN  Entire rental unit
# 22539  Massimo Claudio  2012-02-16                 NaN  Entire rental unit
#
#              room_type    price
# 0      Entire home/apt  $100.00
# ...

# %%
df3= df.iloc[ [1] + [50] + list(range(100, 201)) + [499] + [500] + [605] + [1500] + [8000] + [15000] , : ] 
df3
# Out:
#                         id                                       listing_url  \
# 1                   541221               https://www.airbnb.com/rooms/541221
# 50                  710637               https://www.airbnb.com/rooms/710637
# 100                 806673               https://www.airbnb.com/rooms/806673
# 101                 810216               https://www.airbnb.com/rooms/810216
# 102                 812419               https://www.airbnb.com/rooms/812419
# ...                    ...                                               ...
# 500                3327251              https://www.airbnb.com/rooms/3327251
# 605                5020692              https://www.airbnb.com/rooms/5020692
# 1500              11580800             https://www.airbnb.com/rooms/11580800
# 8000    750503110630802726   https://www.airbnb.com/rooms/750503110630802726
# 15000  1136714556931520755  https://www.airbnb.com/rooms/1136714556931520755
#
# ...

# %%
df4= df.iloc[ [125] + [252] + list(range(300, 551)) + [700] + [1000] + list(range(1250, len(df))) , [9]+ [13]+ [17]+ [35]+ [39] +[71] ] 
df4
# Out:
#          host_id           host_location host_acceptance_rate  bathrooms  \
# 125      2332044  London, United Kingdom                 100%        1.5
# 252      6753357            Milan, Italy                  97%        1.0
# 300      1921860            Milan, Italy                  42%        2.0
# 301      3165404            Milan, Italy                  55%        NaN
# 302     12207778            Milan, Italy                 100%        1.0
# ...          ...                     ...                  ...        ...
# 22535  701379726            Milan, Italy                  NaN        1.0
# 22536    2574070            Milan, Italy                 100%        1.0
# 22537  303593576            Milan, Italy                  79%        1.0
# 22538  701442028                     NaN                  NaN        1.0
# 22539    1761388            Milan, Italy                  88%        1.0
#
#                                                amenities  review_scores_value
# ...

# %%
#Convertir archivo filtrado a CSV
columnas1.to_csv("Array(A).csv")

# %%
#Convertir archivo filtrado a CSV
df3.to_csv("Array(B).csv")

# %%
#Convertir archivo filtrado a CSV
df4.to_csv("Array(C).csv")
